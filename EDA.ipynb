# %% [markdown]
# # IMDbMovies

# %% [markdown]
# ## Contents <a id='back'></a>
#
# 1. [Introduction](#introduction)
# 2. [Loading the Dataset](#loading-the-dataset)
# 3. [Data Cleaning](#data-cleaning)
#    - 3.1 [Header style](#header-style)
#    - 3.2 [Handling Missing Values](#handling-missing-values)
#    - 3.3 [Data Transformation](#data-transformation)
#    - 3.4 [Conclusions](#conclusions)
# 4. [Exploratory Data Analysis (EDA)](#exploratory-data-analysis-eda)
#    - 4.1 [Overview of the Dataset](#overview-of-the-dataset)
#    - 4.2 [Visualizing Data](#visualizing-data)

# %% [markdown]
# ## 1. Introduction <a id='introduction'></a>
#
# The IMDbMovies dataset is a comprehensive collection with information on more than 9000 movies on IMDb. The dataset includes key features such as title, director, writer, genres, runtime, release year, budget, and gross revenue.
#
# The primary goal of this analysis is to gain a deeper insight of the evolution of the cinematographic industry over the years.

# %% [markdown]
# [Back to contents](#back)

# %% [markdown]
# ## 2. Loading the Dataset <a id='loading-the-dataset'></a>
#
# The IMDB Movies dataset is available on [kaggle.com](https://www.kaggle.com/datasets/elvinrustam/imdb-movies-dataset). We will be using the unclean version, so we can carry out our own cleanup.
#
# The first step is to correct a few rows that have the correct data, but it's shifted one column to the right. The movies that require this are:
#
# - Sleepy Hollow
# - Texas Chainsaw
# - G.I. Joe: Retaliation
# - The Woman in the Window
# - The Social Dilemma
# - Bank of Dave
# - Eden
# - CHIPS
# - The Diving Bell and the Butterfly
# - Untamed Heart
# - Roxanne
# - The Postcard Killings
# - Cover Girl
# - The Strangers: Chapter 1
#
# We'll be fixing this with google docs.

# %% [markdown]
# Note that "The Fall of Minneapolis" has a similar issue, but also a lot of missing values, and the value for budget (302) doesn't make sense. We'll drop this row.

# %% [markdown]
# The rest of the preprocessing will be done here. We can load the Dataset now.

# %%
import pandas as pd
import plotly.express as px
import os

data_path = 'datasets'
df = pd.read_csv(os.path.join(data_path, "IMDbMovies.csv"))

# %% [markdown]
# Lets see what the data looks like.

# %%
df.head(5)
# Out:
#                                                Title  \
# 0                                           Napoleon
# 1  The Hunger Games: The Ballad of Songbirds & Sn...
# 2                                         The Killer
# 3                                                Leo
# 4                                       Thanksgiving
#
#                                              Summary  \
# 0  An epic that details the checkered rise and fa...
# 1  Coriolanus Snow mentors and develops feelings ...
# 2  After a fateful near-miss, an assassin battles...
# 3  A 74-year-old lizard named Leo and his turtle ...
# 4  After a Black Friday riot ends in tragedy, a m...
#
#                                             Director  \
# 0                                       Ridley Scott
# 1                                   Francis Lawrence
# 2                                      David Fincher
# 3  David Wachtenheim,Robert Smigel,Robert Marianetti
# 4                                           Eli Roth
#
#                                           Writer                 Main Genres  \
# 0                                   David Scarpa  Action,Adventure,Biography
# 1  Michael Lesslie,Michael Arndt,Suzanne Collins      Action,Adventure,Drama
# 2  Andrew Kevin Walker,Luc Jacamon,Alexis Nolent      Action,Adventure,Crime
# 3           Paul Sado,Robert Smigel,Adam Sandler     Animation,Comedy,Family
# 4                          Eli Roth,Jeff Rendell     Horror,Mystery,Thriller
#
#   Motion Picture Rating Runtime  Release Year  Rating Number of Ratings  \
# 0                     R  2h 38m        2023.0  6.7/10               38K
# 1                 PG-13  2h 37m        2023.0  7.2/10               37K
# 2                     R  1h 58m        2023.0  6.8/10              117K
# 3                    PG  1h 42m        2023.0  7.0/10               10K
# 4                     R  1h 46m        2023.0  7.0/10              9.1K
#
#                      Budget Gross in US & Canada Gross worldwide  \
# 0                       NaN         $37,514,498     $84,968,381
# 1  $100,000,000 (estimated)        $105,043,414    $191,729,235
# 2                       NaN                  NaN       $421,332
# 3                       NaN                  NaN             NaN
# 4                       NaN         $25,408,677     $29,666,585
#
#   Opening Weekend Gross in US & Canada
# 0              $20,638,887Nov 26, 2023
# 1              $44,607,143Nov 19, 2023
# 2                                  NaN
# 3                                  NaN
# 4              $10,306,272Nov 19, 2023

# %% [markdown]
# There seems to be a lot of missing values on the `Budget` and `Gross` columns, and some columns are in a format that is uncomfortable to work with. Time for cleanup.

# %% [markdown]
# [Back to contents](#back)

# %% [markdown]
# ## 3. Data Cleaning <a id="data-cleaning"></a>

# %% [markdown]
# ### 3.1 Header style <a id="header-style"></a>
#
# First we'll fix the names of the existing columns.

# %%
base_columns_names = df.columns
base_columns_names
# Out:
# Index(['Title', 'Summary', 'Director', 'Writer', 'Main Genres',
#        'Motion Picture Rating', 'Runtime', 'Release Year', 'Rating',
#        'Number of Ratings', 'Budget', 'Gross in US & Canada',
#        'Gross worldwide', 'Opening Weekend Gross in US & Canada'],
#       dtype='object')

# %%
fixed_columns_names = {}

for name in base_columns_names:
    fixed_name = name.lower()
    fixed_name = fixed_name.replace(' & ', '&') #turns "us & canada" into "us&canada", to avoid so many '_' characters in the next step
    fixed_name = fixed_name.replace(' ', '_')
    fixed_columns_names [name] = fixed_name

fixed_columns_names
# Out:
# {'Title': 'title',
#  'Summary': 'summary',
#  'Director': 'director',
#  'Writer': 'writer',
#  'Main Genres': 'main_genres',
#  'Motion Picture Rating': 'motion_picture_rating',
#  'Runtime': 'runtime',
#  'Release Year': 'release_year',
#  'Rating': 'rating',
#  'Number of Ratings': 'number_of_ratings',
#  'Budget': 'budget',
#  'Gross in US & Canada': 'gross_in_us&canada',
#  'Gross worldwide': 'gross_worldwide',
#  'Opening Weekend Gross in US & Canada': 'opening_weekend_gross_in_us&canada'}

# %%
df = df.rename(columns = fixed_columns_names)
df.columns
# Out:
# Index(['title', 'summary', 'director', 'writer', 'main_genres',
#        'motion_picture_rating', 'runtime', 'release_year', 'rating',
#        'number_of_ratings', 'budget', 'gross_in_us&canada', 'gross_worldwide',
#        'opening_weekend_gross_in_us&canada'],
#       dtype='object')

# %% [markdown]
# With the columns renamed, lets move on to improving the format of certain columns. We might end up renaming some of them again.

# %% [markdown]
# [Back to contents](#back)

# %% [markdown]
# ### 3.2 Handling Missing Values <a id="handling-missing-values"></a>
#
# First, lets see how many missing values we have to deal with.

# %%
df.isna().sum()
# Out:
# title                                    0
# summary                                  0
# director                                31
# writer                                 324
# main_genres                              7
# motion_picture_rating                  797
# runtime                                165
# release_year                             7
# rating                                 270
# number_of_ratings                      270
# budget                                3203
# gross_in_us&canada                    3018
# gross_worldwide                       1954
# opening_weekend_gross_in_us&canada    3387
# dtype: int64

# %% [markdown]
# Many of these are not critical. We can fill them with `'unknown'` for text columns, or `0` in numerical columns, to mark the data as unavailable, since `0` isn't a value that you would expect to have as a real datapoint in any of these fields.

# %% [markdown]
# The columns `director`, `writer`, `main_genres`, and `motion_picture_rating` can be filled with the value `'unknown'`

# %%
columns_to_fix = ['director', 'writer', 'main_genres', 'motion_picture_rating']

for column in columns_to_fix:
    df[column] = df[column].fillna(value = 'unknown')

# %% [markdown]
# The missing values in the columns `rating`, `number_of_ratings`, `budget`, `gross_in_us&canada`, `gross_worldwide`, and `opening_weekend_gross_in_us&canada` can be filled, but we need to be careful to keep their general format, so the new values don't interfere with data processing.

# %%
# rating is in the format (value/10)
df['rating'] = df['rating'].fillna(value = '0/10')
df['number_of_ratings'] = df['number_of_ratings'].fillna(value = 0)

# %%
# runtime is expressed in hours (h) and minutes (m)
df['runtime'] = df['runtime'].fillna(value = '0m')

# %%
# all entries have a currency, and $ is the most common
columns_to_fix = ['budget', 'gross_in_us&canada', 'gross_worldwide']

for column in columns_to_fix:
    df[column] = df[column].fillna(value = '$0')

# %%
# all entries have the $ at the beginning, followed by the date of the opening weekend
df['opening_weekend_gross_in_us&canada'] = df['opening_weekend_gross_in_us&canada'].fillna(value = '$0Jan 1, 1900')

# %% [markdown]
# The `release_year` is going to be critical. We drop rows that are missing this value.

# %%
df.dropna(subset = ['release_year'], inplace=True)

# %%
df.isna().sum()
# Out:
# title                                 0
# summary                               0
# director                              0
# writer                                0
# main_genres                           0
# motion_picture_rating                 0
# runtime                               0
# release_year                          0
# rating                                0
# number_of_ratings                     0
# budget                                0
# gross_in_us&canada                    0
# gross_worldwide                       0
# opening_weekend_gross_in_us&canada    0
# dtype: int64

# %% [markdown]
# No more missing values. Let's check duplicates.

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# No obvious duplicates.

# %% [markdown]
# Just to make sure, lets double check. We could find duplicates in `title`, but it could still be from different movies. A duplicated `summary` would be more suspicious.

# %%
df['summary'].duplicated().sum()
# Out:
# 32

# %% [markdown]
# There are some duplicates here. Lets see what they are.

# %%
dup = df[df['summary'].duplicated(keep=False)] 
dup = dup.sort_values('summary')

dup
# Out:
#                                                   title  \
# 7803                                            Aladdin
# 557                                             Aladdin
# 5521                                We're the Millers 2
# 6403                                       Real Steel 2
# 3459                    Godzilla x Kong: The New Empire
# 5536                                          Iron Lung
# 2302                                     Fast X: Part 2
# 1144                                    Lethal Weapon 5
# 5319                                   Kind of Kindness
# 8322         Untitled Margot Robbie Ocean's Eleven Film
# 5517                               Community: The Movie
# 6959                                       Red Notice 2
# 6614                         Untitled Spider-Man Sequel
# 423                                  The Batman Part II
# 322                                     Mortal Kombat 2
# 186                                Sonic the Hedgehog 3
# 8394                          The Rivals of Amziah King
# 8557                                          Jim Jones
# 6255                             A Quiet Place Part III
# 8660                                    We Live in Time
# 7908      Untitled Adam Sandler/Safdie Brothers Project
# 4674                                            Smile 2
# 2476                          The Conjuring: Last Rites
# 410                           Untitled Karate Kid Movie
# 546                                             Red One
# 577                          Avengers: The Kang Dynasty
# 753                               Avengers: Secret Wars
# 1885                             A Quiet Place: Day One
# 2170                                          Mickey 17
# 5014  Untitled Monster Thriller for Universal Pictur...
# 9017                            Small Things Like These
# 8883                                     The Underdoggs
# 2511                 Winnie-The-Pooh: Blood and Honey 2
# 3012                                  Sherlock Holmes 3
# 5430                                        Rush Hour 4
# 4788                                National Treasure 3
# 3547             Star Wars: Episode X - A New Beginning
# 715                       Beverly Hills Cop: Axel Foley
# 3388                                 Lady and the Tramp
# 5213                                 Lady and the Tramp
#
#                                                 summary  \
# 7803  A kind-hearted street urchin and a power-hungr...
# 557   A kind-hearted street urchin and a power-hungr...
# 5521                                   Plot is unknown.
# 6403                                   Plot is unknown.
# 3459                             Plot kept under wraps.
# 5536                             Plot kept under wraps.
# 2302                             Plot kept under wraps.
# 1144                             Plot kept under wraps.
# 5319                             Plot kept under wraps.
# 8322                                   Plot under wraps
# 5517                                   Plot under wraps
# 6959                                   Plot under wraps
# 6614                                   Plot under wraps
# 423                                    Plot under wraps
# 322                                    Plot under wraps
# 186                                    Plot under wraps
# 8394                                  Plot under wraps.
# 8557                                  Plot under wraps.
# 6255                                  Plot under wraps.
# 8660                                  Plot under wraps.
# 7908                                  Plot under wraps.
# 4674                                  Plot under wraps.
# 2476                                  Plot under wraps.
# 410                                   Plot under wraps.
# 546                                   Plot under wraps.
# 577                                   Plot under wraps.
# 753                                   Plot under wraps.
# 1885                                  Plot under wraps.
# 2170                                  Plot under wraps.
# 5014                                  Plot under wraps.
# 9017                                  Plot under wraps.
# 8883                                  Plot under wraps.
# 2511                                  Plot under wraps.
# 3012                  The plot is unknown at this time.
# 5430                  The plot is unknown at this time.
# 4788                  The plot is unknown at this time.
# 3547                               The plot is unknown.
# 715                                The plot is unknown.
# 3388  The romantic tale of a sheltered uptown Cocker...
# 5213  The romantic tale of a sheltered uptown Cocker...
#
#                                            director  \
# 7803                                    Guy Ritchie
# 557                        John Musker,Ron Clements
# 5521                        Rawson Marshall Thurber
# 6403                                        unknown
# 3459                                   Adam Wingard
# 5536                                 Mark Fischbach
# 2302                                Louis Leterrier
# 1144                                     Mel Gibson
# 5319                               Yorgos Lanthimos
# 8322                                      Jay Roach
# 5517                                        unknown
# 6959                        Rawson Marshall Thurber
# 6614                                        unknown
# 423                                     Matt Reeves
# 322                                   Simon McQuoid
# 186                                     Jeff Fowler
# 8394                               Andrew Patterson
# 8557                                        unknown
# 6255                                        unknown
# 8660                                   John Crowley
# 7908                       Josh Safdie,Benny Safdie
# 4674                                    Parker Finn
# 2476                                        unknown
# 410                              Jonathan Entwistle
# 546                                     Jake Kasdan
# 577                                         unknown
# 753                                         unknown
# 1885                               Michael Sarnoski
# 2170                                   Bong Joon Ho
# 5014            Tyler Gillett,Matt Bettinelli-Olpin
# 9017                                   Tim Mielants
# 8883                              Charles Stone III
# 2511                          Rhys Frake-Waterfield
# 3012                                Dexter Fletcher
# 5430                                        unknown
# 4788                                        unknown
# 3547                          Sharmeen Obaid-Chinoy
# 715                                     Mark Molloy
# 3388  Hamilton Luske,Clyde Geronimi,Wilfred Jackson
# 5213                                   Charlie Bean
#
#                                                  writer  \
# 7803                            John August,Guy Ritchie
# 557                Ron Clements,John Musker,Ted Elliott
# 5521                                      Adam Sztykiel
# 6403                                        John Gatins
# 3459           Simon Barrett,Jeremy Slater,Terry Rossio
# 5536                     Mark Fischbach,David Szymanski
# 2302                        Oren Uziel,Christina Hodson
# 1144                           Shane Black,Richard Wenk
# 5319                 Efthimis Filippou,Yorgos Lanthimos
# 8322  Jack Golden Russell,George Clayton Johnson,Car...
# 5517                            Dan Harmon,Andrew Guest
# 6959                            Rawson Marshall Thurber
# 6614                                            unknown
# 423              Mattson Tomlin,Matt Reeves,Peter Craig
# 322                   John Tobias,Ed Boon,Jeremy Slater
# 186                               Pat Casey,Josh Miller
# 8394                                   Andrew Patterson
# 8557                                    Scott Rosenberg
# 6255                                     John Krasinski
# 8660                                         Nick Payne
# 7908                           Benny Safdie,Josh Safdie
# 4674                                            unknown
# 2476                    David Leslie Johnson-McGoldrick
# 410                                             unknown
# 546                           Hiram Garcia,Chris Morgan
# 577                                     Michael Waldron
# 753                                     Michael Waldron
# 1885             Scott Beck,Jeff Nichols,John Krasinski
# 2170                         Edward Ashton,Bong Joon Ho
# 5014                         Stephen Shields,Guy Busick
# 9017                           Claire Keegan,Enda Walsh
# 8883  Isaac Schamis,Constance Schwartz-Morini,Danny ...
# 2511       Rhys Frake-Waterfield,A.A. Milne,Matt Leslie
# 3012                  Arthur Conan Doyle,Chris Brancato
# 5430                                       Ross LaManna
# 4788                                      Chris Bremner
# 3547                                      Steven Knight
# 715                 Kevin Etten,Tom Gormican,Will Beall
# 3388              Erdman Penner,Ward Greene,Joe Rinaldi
# 5213                      Kari Granlund,Andrew Bujalski
#
#                      main_genres motion_picture_rating runtime  release_year  \
# 7803     Adventure,Comedy,Family                    PG   2h 8m        2019.0
# 557   Animation,Adventure,Comedy                     G  1h 30m        1992.0
# 5521                      Comedy                     R   2h 3m        2001.0
# 6403         Action,Drama,Family               Unrated  1h 43m        2022.0
# 3459     Action,Adventure,Sci-Fi               unknown      0m        2024.0
# 5536               Horror,Sci-Fi               unknown   2h 1m        2022.0
# 2302       Action,Crime,Thriller               unknown      0m        2025.0
# 1144             Action,Thriller                     R  1h 55m        2018.0
# 5319                     unknown               unknown      0m        2024.0
# 8322                     unknown             Not Rated   2h 5m        1955.0
# 5517                      Comedy               unknown      0m        2024.0
# 6959      Action,Comedy,Thriller                Passed  1h 35m        1942.0
# 6614    Action,Adventure,Fantasy                     R  3h 25m        1966.0
# 423           Action,Crime,Drama               unknown      0m        2025.0
# 322     Action,Adventure,Fantasy                     R  1h 39m        2004.0
# 186      Action,Adventure,Comedy               unknown      0m        2024.0
# 8394              Crime,Thriller                    GP  1h 56m        1971.0
# 8557                     unknown               unknown  1h 35m        2018.0
# 6255         Drama,Horror,Sci-Fi               unknown      0m        2025.0
# 8660               Drama,Romance                     R  1h 32m        2020.0
# 7908                     unknown             Not Rated  1h 22m        1959.0
# 4674     Horror,Mystery,Thriller               unknown      0m        2024.0
# 2476     Horror,Mystery,Thriller                 TV-14   2h 4m        2018.0
# 410          Action,Drama,Family               unknown      0m        2024.0
# 546      Action,Adventure,Comedy               unknown  1h 42m        2024.0
# 577      Action,Adventure,Sci-Fi               unknown      0m        2026.0
# 753      Action,Adventure,Sci-Fi               unknown      0m        2027.0
# 1885         Drama,Horror,Sci-Fi               unknown      0m        2024.0
# 2170      Adventure,Drama,Sci-Fi               unknown      0m        2024.0
# 5014             Horror,Thriller               unknown      0m        2024.0
# 9017                       Drama             Not Rated  1h 37m        1973.0
# 8883                Comedy,Sport                     R      0m        2024.0
# 2511             Horror,Thriller               unknown      0m        2024.0
# 3012    Action,Adventure,Mystery               unknown  2h 22m        2023.0
# 5430     Action,Adventure,Comedy                 PG-13  1h 36m        1985.0
# 4788     Action,Adventure,Family                     R  2h 14m        2002.0
# 3547    Action,Adventure,Fantasy               unknown      0m        2027.0
# 715          Action,Comedy,Crime               unknown      0m        2024.0
# 3388  Animation,Adventure,Comedy                     G  1h 16m        1955.0
# 5213     Adventure,Comedy,Family                    PG  1h 51m        2019.0
#
#       rating number_of_ratings                    budget gross_in_us&canada  \
# 7803  6.9/10              284K  $183,000,000 (estimated)      $355,559,216
# 557   8.0/10              454K   $28,000,000 (estimated)      $217,350,219
# 5521    0/10                 0                        $0                 $0
# 6403    0/10                 0                        $0                 $0
# 3459    0/10                 0                        $0                 $0
# 5536    0/10                 0                        $0                 $0
# 2302    0/10                 0                        $0                 $0
# 1144    0/10                 0                        $0                 $0
# 5319    0/10                 0                        $0                 $0
# 8322    0/10                 0                        $0                 $0
# 5517    0/10                 0                        $0                 $0
# 6959    0/10                 0                        $0                 $0
# 6614    0/10                 0                        $0                 $0
# 423     0/10                 0                        $0                 $0
# 322     0/10                 0                        $0                 $0
# 186     0/10                 0                        $0                 $0
# 8394    0/10                 0                        $0                 $0
# 8557    0/10                 0                        $0                 $0
# 6255    0/10                 0                        $0                 $0
# 8660    0/10                 0                        $0                 $0
# 7908    0/10                 0                        $0                 $0
# 4674    0/10                 0                        $0                 $0
# 2476    0/10                 0                        $0                 $0
# 410     0/10                 0                        $0                 $0
# 546     0/10                 0                        $0                 $0
# 577     0/10                 0                        $0                 $0
# 753     0/10                 0                        $0                 $0
# 1885    0/10                 0                        $0                 $0
# 2170    0/10                 0                        $0                 $0
# 5014    0/10                 0                        $0                 $0
# 9017    0/10                 0                        $0                 $0
# 8883    0/10                 0                        $0                 $0
# 2511    0/10                 0                        $0                 $0
# 3012    0/10                 0                        $0                 $0
# 5430    0/10                 0                        $0                 $0
# 4788    0/10                 0                        $0                 $0
# 3547    0/10                 0                        $0                 $0
# 715     0/10                 0                        $0                 $0
# 3388  7.3/10              145K    $4,000,000 (estimated)       $93,602,326
# 5213  6.2/10               24K                        $0                 $0
#
#       gross_worldwide opening_weekend_gross_in_us&canada
# 7803  $1,054,304,000             $91,500,929May 26, 2019
# 557     $504,050,219                $196,664Nov 15, 1992
# 5521               $0                      $0Jan 1, 1900
# 6403               $0                      $0Jan 1, 1900
# 3459               $0                      $0Jan 1, 1900
# 5536               $0                      $0Jan 1, 1900
# 2302               $0                      $0Jan 1, 1900
# 1144               $0                      $0Jan 1, 1900
# 5319               $0                      $0Jan 1, 1900
# 8322               $0                      $0Jan 1, 1900
# 5517               $0                      $0Jan 1, 1900
# 6959               $0                      $0Jan 1, 1900
# 6614               $0                      $0Jan 1, 1900
# 423                $0                      $0Jan 1, 1900
# 322                $0                      $0Jan 1, 1900
# 186                $0                      $0Jan 1, 1900
# 8394               $0                      $0Jan 1, 1900
# 8557               $0                      $0Jan 1, 1900
# 6255               $0                      $0Jan 1, 1900
# 8660               $0                      $0Jan 1, 1900
# 7908               $0                      $0Jan 1, 1900
# 4674               $0                      $0Jan 1, 1900
# 2476               $0                      $0Jan 1, 1900
# 410                $0                      $0Jan 1, 1900
# 546                $0                      $0Jan 1, 1900
# 577                $0                      $0Jan 1, 1900
# 753                $0                      $0Jan 1, 1900
# 1885               $0                      $0Jan 1, 1900
# 2170               $0                      $0Jan 1, 1900
# 5014               $0                      $0Jan 1, 1900
# 9017               $0                      $0Jan 1, 1900
# 8883               $0                      $0Jan 1, 1900
# 2511               $0                      $0Jan 1, 1900
# 3012               $0                      $0Jan 1, 1900
# 5430               $0                      $0Jan 1, 1900
# 4788               $0                      $0Jan 1, 1900
# 3547               $0                      $0Jan 1, 1900
# 715                $0                      $0Jan 1, 1900
# 3388     $93,933,394              $2,804,272Dec 21, 1986
# 5213               $0                      $0Jan 1, 1900

# %% [markdown]
# Most of the duplicates are from placeholder text. There are two actual duplicated summaries for the movies 'Aladdin' and 'Lady and the Tramp', but correspond to the original film and their remake.
#
# We can be reasonably sure that there are no duplicates in the DataSet.

# %% [markdown]
# [Back to Content](#back)

# %% [markdown]
# ### 3.3 Data Transformation <a id="data-transformation"></a>

# %% [markdown]
# We could benefit from reformatting some of the columns. For easy reference, lets see again what they look like.

# %%
df.head(5)
# Out:
#                                                title  \
# 0                                           Napoleon
# 1  The Hunger Games: The Ballad of Songbirds & Sn...
# 2                                         The Killer
# 3                                                Leo
# 4                                       Thanksgiving
#
#                                              summary  \
# 0  An epic that details the checkered rise and fa...
# 1  Coriolanus Snow mentors and develops feelings ...
# 2  After a fateful near-miss, an assassin battles...
# 3  A 74-year-old lizard named Leo and his turtle ...
# 4  After a Black Friday riot ends in tragedy, a m...
#
#                                             director  \
# 0                                       Ridley Scott
# 1                                   Francis Lawrence
# 2                                      David Fincher
# 3  David Wachtenheim,Robert Smigel,Robert Marianetti
# 4                                           Eli Roth
#
#                                           writer                 main_genres  \
# 0                                   David Scarpa  Action,Adventure,Biography
# 1  Michael Lesslie,Michael Arndt,Suzanne Collins      Action,Adventure,Drama
# 2  Andrew Kevin Walker,Luc Jacamon,Alexis Nolent      Action,Adventure,Crime
# 3           Paul Sado,Robert Smigel,Adam Sandler     Animation,Comedy,Family
# 4                          Eli Roth,Jeff Rendell     Horror,Mystery,Thriller
#
#   motion_picture_rating runtime  release_year  rating number_of_ratings  \
# 0                     R  2h 38m        2023.0  6.7/10               38K
# 1                 PG-13  2h 37m        2023.0  7.2/10               37K
# 2                     R  1h 58m        2023.0  6.8/10              117K
# 3                    PG  1h 42m        2023.0  7.0/10               10K
# 4                     R  1h 46m        2023.0  7.0/10              9.1K
#
#                      budget gross_in_us&canada gross_worldwide  \
# 0                        $0       $37,514,498     $84,968,381
# 1  $100,000,000 (estimated)      $105,043,414    $191,729,235
# 2                        $0                 $0       $421,332
# 3                        $0                 $0              $0
# 4                        $0       $25,408,677     $29,666,585
#
#   opening_weekend_gross_in_us&canada
# 0            $20,638,887Nov 26, 2023
# 1            $44,607,143Nov 19, 2023
# 2                      $0Jan 1, 1900
# 3                      $0Jan 1, 1900
# 4            $10,306,272Nov 19, 2023

# %% [markdown]
# `runtime` is presented in hours + minutes. This format is useful for display, but for comparisons and calculations the runtime in minutes would be much better.

# %%
runtime_minutes=[]

for time in df['runtime']:
    hours = 0
    minutes = 0
    h_pos = time.find('h')
    m_pos = time.find('m')
  
    if h_pos > 0:
        hours = int(time[:h_pos])
    if m_pos > 0:
        minutes = int(time[h_pos+1:-1])
    runtime_minutes.append(hours * 60 + minutes)

df.insert(7, 'runtime_minutes', runtime_minutes)

# %%
df[['runtime', 'runtime_minutes']].head(5)
# Out:
#   runtime  runtime_minutes
# 0  2h 38m              158
# 1  2h 37m              157
# 2  1h 58m              118
# 3  1h 42m              102
# 4  1h 46m              106

# %% [markdown]
# Lets work on the ratings next. The current format is `value/max`, with max being 10 for all entries. We can transform that into a single number, with a range of 0 to 100, so we only deal with integers.
#
# **NOTE:** The movie `This is Spinal Tap` has a max rating of 11, but this is an easter egg, and we can ignore it in our analysis.

# %%
rating_int = []

for rating in df['rating']:
    slash_pos = rating.find('/')
    new_rating = rating[0:slash_pos]
    new_rating = int(new_rating.replace('.', ''))
    rating_int.append(new_rating)

df.insert(10, 'rating_int', rating_int)

# %%
df[['rating', 'rating_int']].head(5)
# Out:
#    rating  rating_int
# 0  6.7/10          67
# 1  7.2/10          72
# 2  6.8/10          68
# 3  7.0/10          70
# 4  7.0/10          70

# %% [markdown]
# Every budget value is `(estimated)`. We can move that to title and clean the values.

# %%
df['budget'] = df['budget'].str.replace('(estimated)', '')

# %%
df = df.rename(columns={'budget': 'budget_estimated'})

# %% [markdown]
# `opening_weekend_gross_in_us&canada` has both the gross revenue and the weekend date. Let's split them.

# %%
dates = []
revenues = []
for value in df['opening_weekend_gross_in_us&canada']:
    date_pos = 0
    for letter in value:
        if letter.isalpha():
            break
        date_pos += 1
    revenue = value[:date_pos]
    date = value[date_pos:]
    dates.append(date)
    revenues.append(revenue)

df.insert(16, 'gross_opening', revenues)
df.insert(17, 'opening_date', dates)

# %%
df[['opening_weekend_gross_in_us&canada', 'gross_opening', 'opening_date']].head(5)
# Out:
#   opening_weekend_gross_in_us&canada gross_opening  opening_date
# 0            $20,638,887Nov 26, 2023   $20,638,887  Nov 26, 2023
# 1            $44,607,143Nov 19, 2023   $44,607,143  Nov 19, 2023
# 2                      $0Jan 1, 1900            $0   Jan 1, 1900
# 3                      $0Jan 1, 1900            $0   Jan 1, 1900
# 4            $10,306,272Nov 19, 2023   $10,306,272  Nov 19, 2023

# %% [markdown]
# Now we can convert `budget_estimated`, `gross_in_us&canada`, `gross_worldwide` and `gross_opening` to int. We need to preserve the currency, since not every movie uses dollars.

# %%
def decimal_pos(value:str):
    nr_pos = 0
    for char in value:
        if char.isdecimal():
            break
        nr_pos += 1
    return nr_pos

# %%
currency = []

for value in df['budget_estimated']:
    nr_pos = decimal_pos(value)
    currency.append(value[:nr_pos])

df.insert(12, 'currency', currency)

# %%
def money_to_int(value_str: str):
    value = value_str[decimal_pos(value_str):]
    value = value.replace(',', '')
    return int(value)

# %%
df['budget_estimated'] = df['budget_estimated'].apply(money_to_int)

# %%
df['gross_in_us&canada'] = df['gross_in_us&canada'].apply(money_to_int)

# %%
df['gross_opening'] = df['gross_opening'].apply(money_to_int)

# %%
df['gross_worldwide'] = df['gross_worldwide'].apply(money_to_int)

# %%
df.head(10)
# Out:
#                                                title  \
# 0                                           Napoleon
# 1  The Hunger Games: The Ballad of Songbirds & Sn...
# 2                                         The Killer
# 3                                                Leo
# 4                                       Thanksgiving
# 5                                        Oppenheimer
# 6                                           Saltburn
# 7                                        The Marvels
# 8                                               Wish
# 9                                        The Creator
#
#                                              summary  \
# 0  An epic that details the checkered rise and fa...
# 1  Coriolanus Snow mentors and develops feelings ...
# 2  After a fateful near-miss, an assassin battles...
# 3  A 74-year-old lizard named Leo and his turtle ...
# 4  After a Black Friday riot ends in tragedy, a m...
# 5  The story of American scientist, J. Robert Opp...
# 6  A student at Oxford University finds himself d...
# 7  Carol Danvers gets her powers entangled with t...
# 8  A young girl named Asha wishes on a star and g...
# 9  Against the backdrop of a war between humans a...
#
#                                             director  \
# 0                                       Ridley Scott
# 1                                   Francis Lawrence
# 2                                      David Fincher
# 3  David Wachtenheim,Robert Smigel,Robert Marianetti
# 4                                           Eli Roth
# 5                                  Christopher Nolan
# 6                                    Emerald Fennell
# 7                                        Nia DaCosta
# 8                      Fawn Veerasunthorn,Chris Buck
# 9                                     Gareth Edwards
#
#                                           writer                 main_genres  \
# 0                                   David Scarpa  Action,Adventure,Biography
# 1  Michael Lesslie,Michael Arndt,Suzanne Collins      Action,Adventure,Drama
# 2  Andrew Kevin Walker,Luc Jacamon,Alexis Nolent      Action,Adventure,Crime
# 3           Paul Sado,Robert Smigel,Adam Sandler     Animation,Comedy,Family
# 4                          Eli Roth,Jeff Rendell     Horror,Mystery,Thriller
# 5      Martin Sherwin,Christopher Nolan,Kai Bird     Biography,Drama,History
# 6                                Emerald Fennell       Comedy,Drama,Thriller
# 7     Elissa Karasik,Nia DaCosta,Megan McDonnell    Action,Adventure,Fantasy
# 8          Jennifer Lee,Chris Buck,Allison Moore  Animation,Adventure,Comedy
# 9                     Chris Weitz,Gareth Edwards      Action,Adventure,Drama
#
#   motion_picture_rating runtime  runtime_minutes  release_year  rating  \
# 0                     R  2h 38m              158        2023.0  6.7/10
# 1                 PG-13  2h 37m              157        2023.0  7.2/10
# 2                     R  1h 58m              118        2023.0  6.8/10
# 3                    PG  1h 42m              102        2023.0  7.0/10
# 4                     R  1h 46m              106        2023.0  7.0/10
# 5                     R      3h              180        2023.0  8.5/10
# 6                     R  2h 11m              131        2023.0  7.5/10
# 7                 PG-13  1h 45m              105        2023.0  6.0/10
# 8                    PG  1h 35m               95        2023.0  5.9/10
# 9                 PG-13  2h 13m              133        2023.0  6.9/10
#
#    rating_int number_of_ratings currency  budget_estimated  \
# 0          67               38K        $                 0
# 1          72               37K        $         100000000
# 2          68              117K        $                 0
# 3          70               10K        $                 0
# 4          70              9.1K        $                 0
# 5          85              525K        $         100000000
# 6          75              7.7K        $                 0
# 7          60               57K        $         220000000
# 8          59              6.4K        $         200000000
# 9          69               79K        $          80000000
#
#    gross_in_us&canada  gross_worldwide opening_weekend_gross_in_us&canada  \
# 0            37514498         84968381            $20,638,887Nov 26, 2023
# 1           105043414        191729235            $44,607,143Nov 19, 2023
# 2                   0           421332                      $0Jan 1, 1900
# 3                   0                0                      $0Jan 1, 1900
# 4            25408677         29666585            $10,306,272Nov 19, 2023
# 5           325367020        950554020            $82,455,420Jul 23, 2023
# 6             4358312          7545932               $322,651Nov 19, 2023
# 7            77926655        188196816            $46,110,859Nov 12, 2023
# 8            33974306         51276049            $19,698,228Nov 26, 2023
# 9            40774679        104181028             $14,079,512Oct 1, 2023
#
#    gross_opening  opening_date
# 0       20638887  Nov 26, 2023
# 1       44607143  Nov 19, 2023
# 2              0   Jan 1, 1900
# 3              0   Jan 1, 1900
# 4       10306272  Nov 19, 2023
# 5       82455420  Jul 23, 2023
# 6         322651  Nov 19, 2023
# 7       46110859  Nov 12, 2023
# 8       19698228  Nov 26, 2023
# 9       14079512   Oct 1, 2023

# %% [markdown]
# Sometimes `director` has notes enclosed within parenthesis. Those could cause issues. Lets clean that.

# %%
def clean_parenthesis(text:str):
    open_p = text.find('(')
    close_p = text.find(')')
    if close_p > open_p:
        text = text[:open_p] + text[close_p + 1:]
        text = clean_parenthesis(text) # We use recursion in case there are cases with multiple notes.
    return text

df['director'] = df['director'].apply(clean_parenthesis)

# %% [markdown]
# Some of these columns are no longer needed. We can drop them.

# %%
df.drop(columns = ['rating', 'opening_weekend_gross_in_us&canada'], inplace=True)

# %% [markdown]
# Now that the Dataset is ready, let's save it.

# %%
df.to_csv(os.path.join(data_path, 'IMDbMovies_clean.csv'))

# %% [markdown]
# [Back to Contents](#back)

# %% [markdown]
# ## 3.4 Conclusions <a id='conclusions'></a>

# %% [markdown]
# We corrected several issues with the Dataset:
#
# - Fixed header styles
# - Filled missing values
# - Reformated several columns
#
# The headers were fixed to make processing simpler.
#
# All missing values were replaced with appropiate values that keep the format of the data they are in.
#
# We checked for duplicates, and didn't find any.
#
# Reformated several columns to ease access to their values.
#
# We are ready to start with EDA.

# %% [markdown]
# [Back to Contents](#back)

# %% [markdown]
# ## 4. Exploratory Data Analysis (EDA) <a id="exploratory-data-analysis-eda"></a>

# %% [markdown]
# ### 4.1 Overview of the Dataset <a id="overview-of-the-dataset"></a>

# %% [markdown]
# Lets start exploring our DataSet. We can begin by checking the range of years that we have to work with, and how many movies per year.

# %%
min_year = df['release_year'].min()
max_year = df['release_year'].max()

print(f'The earliest movie is from: {min_year}.\nThe latest movie is from: {max_year}')
# Out:
# The earliest movie is from: 1915.0.
# The latest movie is from: 2027.0

# %%
fig = px.histogram(df, x='release_year', histfunc='count')
fig.show()

# %% [markdown]
# There isn't much info on the first half of the century. Only after 1950 we consistently have more than 10 movies per year. Most of the data is from the last 40 years.

# %% [markdown]
# [Back to Contents](#back)

# %% [markdown]
# ### 4.2 Visualizing Data <a id="visualizing-data"></a>

# %% [markdown]
# Movies have become more expensive to produce in the last years. But how much? and when did this trend start?

# %%
# a budget of 0 means the data is missing from our DataSet
filtered_budget = df[df['budget_estimated'] != 0]
# It's quite hard to find exchange data from before 1990. We'll only use dollars
filtered_budget = filtered_budget[filtered_budget['currency'] == '$']

fig = px.histogram(filtered_budget, x='release_year', y='budget_estimated', histfunc='avg')
fig.show()

# %% [markdown]
# The trend started slightly before the 80's, accelerated during the 90's, and pretty much stopped around the 2000.

# %% [markdown]
# And how much money did they make in those years? Was the cost increase worth it?

# %%
# a gross of 0 means the data is missing from our DataSet
filtered_gross = df[df['gross_worldwide'] != 0]
# It's quite hard to find exchange data from before 1990. We'll only use dollars
filtered_gross = filtered_gross[filtered_gross['currency'] == '$']

fig = px.histogram(filtered_gross, x='release_year', y='gross_worldwide', histfunc='avg')
fig.show()

# %% [markdown]
# The gross revenue has, in general, increased together with the cost of production. There is a sharp drop in 2020, showing the effects of covid-19 on the cinematographic industry. And it hasn't recovered yet. Right now the industry is on the revenue level of the late 80's.

# %% [markdown]
# What happened around 1940? Apparently there were some extremely successful movies. Let's find them.

# %%
max_gross_index = filtered_gross[filtered_gross['release_year'].isin(range(1937, 1943))].groupby('release_year')[['gross_worldwide']].idxmax()
filtered_gross.loc[max_gross_index['gross_worldwide'], ['release_year', 'title', 'budget_estimated', 'gross_worldwide']]
# Out:
#       release_year                            title  budget_estimated  \
# 1203        1937.0  Snow White and the Seven Dwarfs           1499000
# 8079        1938.0                The Lady Vanishes                 0
# 251         1939.0               Gone with the Wind           3977000
# 3966        1940.0                        Pinocchio           2600000
# 917         1941.0                     Citizen Kane            839727
# 4914        1942.0                            Bambi                 0
#
#       gross_worldwide
# 1203        184960471
# 8079            39776
# 251         402382193
# 3966        121892045
# 917           1645944
# 4914        267447150

# %% [markdown]
# Here they are.
#
# - Snow White (1937): $185M
# - Gone with the Wind (1939): $402M
# - Pinocchio (1940): $122M
# - Bambi (1942): $267M
#
# Those were good years for Disney.

# %% [markdown]
#  Let's take a look at the full picture.

# %%
fig = px.scatter(filtered_gross, x='release_year', y='gross_worldwide', hover_data=['title'])
fig.show()

# %% [markdown]
# Now lets take a look at the evolution of genres.

# %%
# List of all the genre classifications on IMDb
genres = set()

for line in df['main_genres'].unique():
    for genre in line.split(','):
        genres.add(genre.strip())

genres.discard('unknown') # This marks missing data, so it's not needed.
genres
# Out:
# {'Action',
#  'Adventure',
#  'Animation',
#  'Biography',
#  'Comedy',
#  'Crime',
#  'Documentary',
#  'Drama',
#  'Family',
#  'Fantasy',
#  'Film-Noir',
#  'History',
#  'Horror',
#  'Music',
#  'Musical',
#  'Mystery',
#  'Romance',
#  'Sci-Fi',
#  'Sport',
#  'Thriller',
#  'War',
#  'Western'}

# %%
selected_genre = 'Action'
selected_datapoint = 'budget_estimated'

# Filter out currencies other than $, so we can comfortably chart for revenue and budget.
filtered_dollar_df = df[df['currency'] == '$']
selected_genre_df = filtered_dollar_df[filtered_dollar_df['main_genres'].str.contains(selected_genre)]

fig = px.scatter(selected_genre_df, x='release_year', y=selected_datapoint, hover_data=['title'])
fig.show()

# %% [markdown]
# Does a higher budget correlate with higher revenue?

# %%
fig = px.scatter(filtered_dollar_df, x='budget_estimated', y='gross_worldwide', hover_data=['title', 'release_year'])
fig.show()

# %% [markdown]
# Lets see which are the most profitable directors.

# %%
# List of all the directors
directors = set()

for line in filtered_dollar_df['director'].unique():
    
    for d in line.split(','):
        directors.add(d.replace('(*)', '').strip())

#directors.discard('unknown') # This marks missing data, so it's not needed.
directors
# Out:
# {'Billy Ray',
#  'Channing Tatum',
#  'Brandon Cronenberg',
#  'Indar Dzhendubaev',
#  'Assaf Bernstein',
#  'Otto Jongerius',
#  'Stephen Meek',
#  'Garth Jennings',
#  'Brandon Christensen',
#  'Michele Massimo Tarantini',
#  'Lisa Azuelos',
#  'Ben Palmer',
#  'Leslye Headland',
#  'Andrew Ahn',
#  'Mark Cullen',
#  'Frank Henenlotter',
#  'Dominic Sena',
#  'Jean-Marc Vallée',
#  'A.K. Sajan',
#  'Mario Van Peebles',
#  'Asif Kapadia',
#  'Bob Saget',
#  'Milos Forman',
#  'Matt Brown',
#  'Richard Stanley',
#  'Nigel Cole',
#  'Meredith Bragg',
#  'Ken Annakin',
#  'Malcolm D. Lee',
#  'Andrew Renzi',
#  'Marc Abraham',
#  'Mike Marvin',
#  'Carlota Pereda',
#  'James Watkins',
#  'Sarah Smith',
#  'André van Duren',
#  'Ralph Bakshi',
#  'Jay Lee',
#  'Patrick Magee',
#  'Kent Alterman',
#  'Devin Sanchez',
#  'Hannah Barlow',
#  'Dan Mazer',
#  'Blair Hayes',
#  'Kevin Sorbo',
#  'John Maybury',
#  'Ka-Wai Kam',
#  'Tom Savini',
#  'Mick Jackson',
#  'Eddie Sternberg',
#  'Mel Ferrer',
#  'William Olsson',
#  'Leonard Nimoy',
#  'Edward Yang',
#  'Matt Johnson',
#  'Qui Nguyen',
#  'Bill Holderman',
#  'Lance Young',
#  'Aurélia Georges',
#  'Andres Beltran',
#  'Steven Seagal',
#  'Pete Travis',
#  'Dave Monahan',
#  'Craig Zobel',
#  'Peter Saunders',
#  'Gina Prince-Bythewood',
#  'Phillip Borsos',
#  'John Caird',
#  'Tobias Lindholm',
#  'Fred Fleck',
#  'Joe Swanberg',
#  'Nikkhil Advani',
#  'Greg Pritikin',
#  'Paul Briganti',
#  'Andrey Konchalovskiy',
#  'Irwin Winkler',
#  'Jeanne Herry',
#  'Katt Shea',
#  'Jim Jarmusch',
#  'John R. Leonetti',
#  'Dario Argento',
#  'Ben Falcone',
#  'Darren Stein',
#  'Lasse Hallström',
#  'Richard Shepard',
#  'Alan Ormsby',
#  'Brett Leonard',
#  'Robert Chandler',
#  'Tom Harper',
#  'William Castle',
#  'Farhad Safinia',
#  'John Lee',
#  'Rudolph Maté',
#  'Cory Evans',
#  'Billy Wilder',
#  'Sara Zandieh',
#  'Richard Donner',
#  'Matt Ross',
#  'Paul Greengrass',
#  'David Nutter',
#  'Young-Keun Min',
#  'Molly McGlynn',
#  'Marlon Brando',
#  'Don Sharp',
#  'David Hackl',
#  'Meg Leonard',
#  'Jonás Cuarón',
#  'Ana Lily Amirpour',
#  'Joe Johnston',
#  'Faryn Pearl',
#  'Woo-Ping Yuen',
#  'Jeff Schaffer',
#  'Michael Goetz',
#  'Brian Klugman',
#  'David Ayer',
#  'Stephen Moyer',
#  'Toshiya Fujita',
#  'Nida Manzoor',
#  'Jeff Tremaine',
#  'Simon Barrett',
#  'Bill Burr',
#  'Anthony C. Ferrante',
#  'François Simard',
#  'Betty Kaplan',
#  'Benjamin Rocher',
#  'D.W. Griffith',
#  'Rose Glass',
#  'Jonas Åkerlund',
#  'Silvio Soldini',
#  'Paul Dano',
#  'Stéphan Castang',
#  'Robin Wright',
#  'Steven Siig',
#  'Yevheniy Yermak',
#  'Sung Kang',
#  'Nikolai Malden',
#  'Richard Ayoade',
#  'Christine Jeffs',
#  'Mukunda Michael Dewil',
#  'Karim Aïnouz',
#  'Janeen Damian',
#  'Jerome Robbins',
#  'Julien Hollande',
#  'Chuck Russell',
#  'George Marshall',
#  'Warren Brock',
#  'Karoline Herfurth',
#  'Aku Louhimies',
#  'Rhys Frake-Waterfield',
#  'Henry Selick',
#  'Mehmet Binay',
#  'Susan Stroman',
#  'Charles Marquis Warren',
#  'Januel Mercado',
#  'Motonori Sakakibara',
#  'David Gelb',
#  'Emma Tammi',
#  'Andrew Jacobson',
#  'Pawel Pawlikowski',
#  'Elaine May',
#  'Paul Briggs',
#  'Dave Filoni',
#  'Amanda McBaine',
#  'Amos Poe',
#  'Peter Howitt',
#  'Tony Bill',
#  'Brad Keller',
#  'Steven S. DeKnight',
#  'Alfredo Barrios Jr.',
#  'Gregor Jordan',
#  'Charlie Day',
#  'Andy Sidaris',
#  'Anne Fletcher',
#  'Krzysztof Kieslowski',
#  'Sydney Sibilia',
#  'Just Jaeckin',
#  'Mike Mitchell',
#  'Leslie Small',
#  'Rick Rosenthal',
#  'Phil Tippett',
#  'Marc Lawrence',
#  'Michael Powell',
#  'Justin Kurzel',
#  'Siddharth Anand',
#  'Mehmet Ada Öztekin',
#  'Charley Rogers',
#  'Chad Ferrin',
#  'Jason Abrams',
#  'Norman Z. McLeod',
#  'Jack Ayers',
#  'Ricky Gervais',
#  'Carlos Saldanha',
#  'Kim Farrant',
#  'Jay Russell',
#  'Aaron Moorhead',
#  'William Cottrell',
#  'Seth MacFarlane',
#  'Walter Hill',
#  'Phil Blattenberger',
#  'François Truffaut',
#  'Director X',
#  'Coralie Trinh Thi',
#  'Todd Haynes',
#  'Vuk Lungulov-Klotz',
#  'David Blue Garcia',
#  'Kristina Buozyte',
#  'Lon Chaney',
#  'Paul W.S. Anderson',
#  'Sean Durkin',
#  'Dexter Fletcher',
#  'Roxann Dawson',
#  'Matt Bettinelli-Olpin',
#  'Borja Brun',
#  'Fred Manocherian',
#  'Casper Christensen',
#  'Ridley Scott',
#  'Timothy Woodward Jr.',
#  'Bradley Parker',
#  'Christopher Zalla',
#  'Eskil Vogt',
#  'Deborah Kaplan',
#  'Tim McCanlies',
#  'Ari Novak',
#  'Bob Spiers',
#  'Phillip Noyce',
#  'Ayan Mukerji',
#  'Javier Reyna',
#  'Wilson Yip',
#  'Talia Osteen',
#  'Greg Beeman',
#  'Sam Boyd',
#  'Edward Zwick',
#  'Phyllis Nagy',
#  'Arlene Sanford',
#  'Gabriela Tagliavini',
#  'Pascal Laugier',
#  'Mark Levin',
#  'Albert Pintó',
#  'Anthony Hemingway',
#  'Michael Hoffman',
#  'Yoshifumi Kondô',
#  'Kenya Barris',
#  'J.C. Chandor',
#  'Robert Schwentke',
#  'Declan Lawn',
#  'Park Hee-kon',
#  'Tony Bancroft',
#  'Ward Kimball',
#  'Damian Kulash',
#  'Adam Mason',
#  'Bille August',
#  'Steve Bendelack',
#  'Jon Wright',
#  'Joby Harold',
#  'Ethan Maniquis',
#  'Jason Moore',
#  'Joel Zwick',
#  'Nick Lieberman',
#  'Charles Guard',
#  'Jonathan English',
#  'Tim Burton',
#  'Nick Hurran',
#  'Don Edmonds',
#  'Max Winkler',
#  'Ethan Hawke',
#  'Octavio E. Rodriguez',
#  'Jim Fall',
#  'Ryan Fleck',
#  'Ariel Schulman',
#  'Daniel Barber',
#  'Randall Miller',
#  'Carl Gottlieb',
#  'Demian Lichtenstein',
#  'William Oldroyd',
#  'Sean Hoessli',
#  'Wilfred Jackson',
#  'John Hamburg',
#  'Michael Winterbottom',
#  'Peter Kosminsky',
#  'Dax Shepard',
#  'Robert Cullen',
#  'Matt Smith',
#  'Robert Pulcini',
#  'David Seltzer',
#  'James Michael Cummings',
#  'Prueksa Amaruji',
#  'Vincenzo Conrorio',
#  'David Robert Mitchell',
#  'Pushkar',
#  'Jack Nicholson',
#  'Richard LaGravenese',
#  'Harold Becker',
#  'Peter R. Hunt',
#  'Luka Hrgovic',
#  'Corin Hardy',
#  'Thurop Van Orman',
#  'Jack Clayton',
#  'Eli Horowitz',
#  'Fritz Kiersch',
#  'Trevor Kirschner',
#  'Key Mangunsong',
#  'Scott Mosier',
#  'Guy Nattiv',
#  'Mike Johnson',
#  'Rupert Goold',
#  'Jack C. Newell',
#  'McG',
#  'Roman Perez Jr.',
#  'Dean McKendrick',
#  'Gustavo Loza',
#  'Sam Fell',
#  'Georges Franju',
#  'Alex Cox',
#  'James Bridges',
#  'Colm Bairéad',
#  'Gabe Polsky',
#  'Eric Goldberg',
#  'Zalman King',
#  'Jennifer Kent',
#  'Mitchell Lichtenstein',
#  'David Leland',
#  'Gianfranco Mingozzi',
#  'David Helling',
#  'Xavier Gens',
#  'Aneesh Chaganty',
#  'Derek Drymon',
#  'Peter Yates',
#  'Tilman Singer',
#  'Andrea Pallaoro',
#  'Benny Boom',
#  'Sudipto Sen',
#  'Francis Annan',
#  'Brian Henson',
#  'Bill Pohlad',
#  'Parker Phillips',
#  'Shana Feste',
#  'Alexander Witt',
#  'Gerald Thomas',
#  'Zachary Wigon',
#  'Pete Walker',
#  'David Worth',
#  'Jean-Luc Godard',
#  'Jean Yarbrough',
#  'Óskar Thór Axelsson',
#  'T. Hee',
#  'Rob Cohen',
#  'Lee Toland Krieger',
#  'Alice Troughton',
#  'John Stalberg Jr.',
#  'Jack Donohue',
#  'Gary Trousdale',
#  'Roy Ward Baker',
#  'Zelda Williams',
#  'Ford Beebe Jr.',
#  'Héctor Olivera',
#  'Jay Arnold',
#  'Sean Anders',
#  'Tali Shalom-Ezer',
#  'Jeremy Saulnier',
#  'B.J. Novak',
#  'Herk Harvey',
#  'Alfred Hitchcock',
#  'Tamra Davis',
#  'Joel Souza',
#  "Pat O'Connor",
#  'Stephen Shimek',
#  'Bob Rafelson',
#  'Steve Carver',
#  'Takeshi Koike',
#  'Jahmil X.T. Qubeka',
#  'Mani Ratnam',
#  'Pierre Coffin',
#  'Jeffrey Walker',
#  'Roland Emmerich',
#  'Angelina Jolie',
#  'Ross Duffer',
#  'Petr Jákl',
#  'Jon M. Chu',
#  'Lin Oeding',
#  'Colin West',
#  'Todd Wilderman',
#  'Nobuhiko Ôbayashi',
#  'Chris Williams',
#  'Paul Feig',
#  'George Sluizer',
#  'Sean Mullin',
#  'Russell Mulcahy',
#  'Jeffrey Bloom',
#  'Ronny Yu',
#  'Gabor Csupo',
#  'Victor Levin',
#  'Allan Ungar',
#  'Lindsay Hartley',
#  'Luis Llosa',
#  'Björn Runge',
#  'Nima Nourizadeh',
#  'Darin Scott',
#  'Greg Tiernan',
#  'Aaron Burns',
#  'Jean-Claude Van Damme',
#  'Afonso Poyart',
#  'Brian Brough',
#  'Brian Percival',
#  'Howard Hawks',
#  'John Landis',
#  'Jeff Wadlow',
#  'Hideo Nakata',
#  'Gregory Widen',
#  'DK Welchman',
#  'Wei Lo',
#  'Nicholas Tana',
#  'John Adams',
#  'Sam J. Levine',
#  'Hallie Meyers-Shyer',
#  'Rolf de Heer',
#  'Anthony Harvey',
#  'Vaughn Stein',
#  'Rebekah McKendry',
#  'Steve Kloves',
#  "Liam O'Donnell",
#  'Sophie Barthes',
#  'Walt Dohrn',
#  'Renny Harlin',
#  'Stelios Kammitsis',
#  'Peter Chelsom',
#  'Sid Sadowskyj',
#  'Jeff Chan',
#  'Ron Shelton',
#  'Alejandro Brugués',
#  'Gene Quintano',
#  'Jessica Sharzer',
#  'Sean Charmatz',
#  'Ram Gopal Varma',
#  'Kristin Gore',
#  'Derek Cianfrance',
#  'Bart Freundlich',
#  'David Zucker',
#  'Richard C. Sarafian',
#  'Carl Goldstein',
#  'Victor Salva',
#  'Sean Penn',
#  'Lee Daniels',
#  'David Gordon Green',
#  'Ashutosh Gowariker',
#  'Neasa Hardiman',
#  'Clark Gregg',
#  'Stephen Hopkins',
#  'Jesper Ganslandt',
#  'Wendy Faraone',
#  'Christopher Fox',
#  'Sophia Takal',
#  'Sean Byrne',
#  'Robert Aldrich',
#  'Matthew Bright',
#  'Charles Vidor',
#  'Alex Hardcastle',
#  'Kabir Khan',
#  'Pier Giuseppe Murgia',
#  'Mstyslav Chernov',
#  'Callum Burn',
#  'Stevan Mena',
#  'Marc Forster',
#  'Eduard Abalov',
#  'John Fortenberry',
#  'Ben Lewin',
#  'George Lucas',
#  'Hugo Fregonese',
#  'Dean Parisot',
#  'Roger Avary',
#  'Matthew Vaughn',
#  'Bryan Spicer',
#  'Andrew Bergman',
#  'Hark Tsui',
#  'Ate de Jong',
#  'Kyle Newman',
#  'Edward D. Wood Jr.',
#  'Ramón Menéndez',
#  'Betty Thomas',
#  'Hugh Welchman',
#  'Edgar G. Ulmer',
#  'Yong Duk Jhun',
#  'Sam Taylor-Johnson',
#  'Arthur Hiller',
#  'Kerry Bellessa',
#  'Jirí Vejdelek',
#  'James Frawley',
#  'Alessandro Carloni',
#  'Juel Taylor',
#  'Lawrence Kasdan',
#  'Karey Kirkpatrick',
#  'Franco Zeffirelli',
#  'Vincent McEveety',
#  'Sam Eilertsen',
#  'Peter Segal',
#  'Ruben Östlund',
#  'Barbra Streisand',
#  'Daniel Petrie',
#  'Ben J. Williams',
#  'Edward Dmytryk',
#  'Paul T. Scheuring',
#  'R.J. Cutler',
#  'Janicza Bravo',
#  'Fred Searle',
#  'Tom Six',
#  'Taichi Ishidate',
#  'Tanya Wexler',
#  'Joseph Gordon-Levitt',
#  'Scott Cooper',
#  'Pat Holden',
#  'Steven Pierce',
#  'Lulu Wang',
#  'Yasushi Kawamura',
#  'Thom Harp',
#  'Angus MacLane',
#  'Gregory Hoblit',
#  'Jessica Yu',
#  'Michael Polish',
#  'Kalyan Shankar',
#  'Brian DeCubellis',
#  'Claire McCarthy',
#  'Paloma Baeza',
#  'David Slade',
#  'John Trengove',
#  'Douglas Sirk',
#  'Rod Lurie',
#  'BenDavid Grabinski',
#  'Werner Herzog',
#  'Mikael Håfström',
#  'Christopher Cain',
#  'T.J. Gnanavel',
#  'Alexis Jacknow',
#  'Brian Desmond Hurst',
#  'Rob Greenberg',
#  'Asger Leth',
#  'James Foley',
#  'Iwao Takamoto',
#  'Jeff Beesley',
#  'Christopher Scott Bradshaw',
#  'Peter Medak',
#  'Ethan Coen',
#  'Michael Laicini',
#  'Israel Horovitz',
#  'Géla Babluani',
#  'Andrew Jarecki',
#  'Robert Benton',
#  'Pixote Hunt',
#  'James Marsh',
#  'Scott Mann',
#  'Jordan Vogt-Roberts',
#  'Steven Kostanski',
#  'Lawrence Sher',
#  'Patrick Hughes',
#  'Drew T. Pierce',
#  'Elise Raven',
#  'Jim Drake',
#  'Stephen Kessler',
#  'Aaron Schneider',
#  'Peter Huyck',
#  'Anthony Squire',
#  'John Huston',
#  'Julie R. Ølgaard',
#  'Edward Lachman',
#  'Drew Goddard',
#  'William T. Hurtz',
#  'Ol Parker',
#  'Peter Hyams',
#  'Ron Clements',
#  'Philip Haas',
#  'Jay Baruchel',
#  'Thomas Kail',
#  'Mark Rosman',
#  'John Turturro',
#  'David P. Smith',
#  'Dorian Walker',
#  'Josephine Decker',
#  'John Curran',
#  'Gerard Barrett',
#  'Will Sharpe',
#  'Paul Mazursky',
#  'Jenna Laurenzo',
#  'Nacho Vigalondo',
#  'Matthew Ross',
#  'Ingmar Bergman',
#  'Floyd Mutrux',
#  'James Kelley',
#  'Steve Oedekerk',
#  'Luke Cormican',
#  'Jong-Yeol Baek',
#  'Stephan Rick',
#  'Derek Tsang',
#  'Ronald Neame',
#  'Steve Box',
#  'Eric Summer',
#  'Rebecca Zlotowski',
#  'Daniel Myrick',
#  'Joe Chappelle',
#  'Felix Herngren',
#  'Lindsay Gossling',
#  'James Sbardellati',
#  'Blair Moore',
#  'Olaf de Fleur Johannesson',
#  'Jean-Pierre Jeunet',
#  'Halina Reijn',
#  'Jonathan Liebesman',
#  'Susanna White',
#  'Arie Posin',
#  'Nick Lyon',
#  'Debra Granik',
#  'Dave Green',
#  'Delphine Lehericey',
#  'Adrian Lyne',
#  'Ramin Bahrani',
#  'Will Price',
#  'Amma Asante',
#  'Nancy Meyers',
#  'Arlen Konopaki',
#  'Jack Hill',
#  'Dito Montiel',
#  'Adrian Bol',
#  'Robert Iscove',
#  'Joel Edgerton',
#  'Matt Duffer',
#  'Chiwetel Ejiofor',
#  'Kevin Goetz',
#  'Fran Rubel Kuzui',
#  'Kyle Rankin',
#  'Eiichi Yamamoto',
#  'Kunihiko Yuyama',
#  'Ali Abbasi',
#  'Klay Hall',
#  'Sam H. Freeman',
#  'Nicolas Harvard',
#  'James Lapine',
#  'Anthony Scott Burns',
#  'Eugene Levy',
#  'Cary Joji Fukunaga',
#  'Ilker Çatak',
#  'Richard John Taylor',
#  'Emin Alper',
#  'Sung-hyun Byun',
#  'Stephen Susco',
#  'Jim Henson',
#  'Camille Griffin',
#  'George Cukor',
#  'Ole Bornedal',
#  'Jerry Kramer',
#  'Fabrice Canepa',
#  'Karim Ouelhaj',
#  'Benjamin Renner',
#  'Michael Patrick Jann',
#  'Jayson Thiessen',
#  'Guy Jenkin',
#  'Benny Safdie',
#  'David Cronenberg',
#  'Fisher Stevens',
#  'David Dobkin',
#  'Greg Mottola',
#  'Shainee Gabel',
#  'Ivan Sen',
#  'Jo-Anne Brechin',
#  'Ishirô Honda',
#  'Shane Dax Taylor',
#  'Numa Perrier',
#  'Gideon Raff',
#  'Charles Kinnane',
#  'Tim Robbins',
#  'Lili Fini Zanuck',
#  'Bob Persichetti',
#  'Yimou Zhang',
#  'Henry Joost',
#  'Gareth Evans',
#  'Alex Brewer',
#  'Gia Coppola',
#  'Richard Rush',
#  'Joel Schumacher',
#  'Madonna',
#  'Uli Edel',
#  'Volker Schlöndorff',
#  'Matt Spicer',
#  'David Lean',
#  'Christopher McQuarrie',
#  'Nicholas D. Johnson',
#  'Robin Bain',
#  'Christian Nyby',
#  'Robin Hardy',
#  'John Pasquin',
#  'Srinivas Omkar',
#  'Nour Wazzi',
#  'John Alan Schwartz',
#  'Fabio Guaglione',
#  'Buck Henry',
#  'Damien Dante Wayans',
#  'Sreedhar Swaraghav',
#  'Vishnu Bharathan',
#  'Pau Masó',
#  'Donovan Marsh',
#  'J.J. Perry',
#  'Murat Saraçoglu',
#  'Peyton Reed',
#  'Austin Bragg',
#  'Aaron Sorkin',
#  'Robert Milton',
#  'Louis Leterrier',
#  'Otto Bathurst',
#  'Ash Brannon',
#  'Baltasar Kormákur',
#  'Peter Hall',
#  'Steve Beck',
#  'Michael Rymer',
#  'Stephen Herek',
#  'Pippa Ehrlich',
#  'Eddie Arya',
#  'Michael Herz',
#  'Luke Snellin',
#  'Shane Acker',
#  'Oleksandra Ruban',
#  'Bruce Robinson',
#  'Damián Romay',
#  'Michel Franco',
#  'Jay Sandrich',
#  'Jeymes Samuel',
#  'Brad Furman',
#  'Matthew Gentile',
#  'Robert Wise',
#  'Maria Sadowska',
#  'Rod Hardy',
#  'Mike Barker',
#  'Oliver Park',
#  'Jan de Bont',
#  'Christophe Honoré',
#  'Gail Lerner',
#  'Ernst Laemmle',
#  'Aaron Hann',
#  'Burt Kennedy',
#  'Scott Elliott',
#  'Carlos Carrera',
#  'Morgan S. Dalibert',
#  'Michele Soavi',
#  'Dan Kuenster',
#  'Mia Hansen-Løve',
#  'Wash Westmoreland',
#  'Demián Rugna',
#  'Mike Judge',
#  'Lawrence Guterman',
#  'John McTiernan',
#  'Gregory Plotkin',
#  'Molly Gordon',
#  'Frank Darabont',
#  'Troy Nixey',
#  'Christopher Smith',
#  'Benjamin Bryant',
#  'Skye Braband',
#  'Ellory Elkayem',
#  'Nathan Frankowski',
#  'Max Barbakow',
#  'Joseph Ruben',
#  'Vince Gilligan',
#  'Dave Thomas',
#  'Sidney Gilliat',
#  'Duncan Skiles',
#  'Dick Zondag',
#  'Todd Edwards',
#  'Chris Columbus',
#  'Brett Simmons',
#  'Frank Marshall',
#  'Isabelle Stever',
#  'Randy Barbato',
#  'Eric Bress',
#  'David Maysles',
#  'Augustine Frizzell',
#  'Wolfgang Petersen',
#  'Sergey Bondarchuk',
#  'Patrick Vollrath',
#  'Florian Westermann',
#  'Topel Lee',
#  'Kevin Lima',
#  'Anthony Hickox',
#  'Kristin Scott Thomas',
#  'Jerren Lauder',
#  'Liz Garbus',
#  'Benny Chan',
#  'Stephen Karam',
#  'Jason Woliner',
#  'Paul Gross',
#  'George Ogilvie',
#  'Romuald Boulanger',
#  'Jon Cassar',
#  'Sidney Lumet',
#  'Stuart Gillard',
#  'Tosca Musk',
#  'Barry Shear',
#  'Damian Lee',
#  'Waymon Boone',
#  'Alfred Sole',
#  'Andrew Legge',
#  'Giuseppe Fiorello',
#  'Zelda Adams',
#  'J. Mackye Gruber',
#  'Brett Haley',
#  'Adam Marcus',
#  'Steven Luke',
#  'Dick Maas',
#  'Brad Peyton',
#  'Jesse Moss',
#  'Nicolás Onetti',
#  'Abdellatif Kechiche',
#  'Bill Melendez',
#  'Diego Hallivis',
#  'Paul Hyett',
#  'Hansal Mehta',
#  'Alister Grierson',
#  'Jim Archer',
#  'Sam Macaroni',
#  'David Hayter',
#  'Cory Morrison',
#  'Ron Fricke',
#  'Glenn Gordon Caron',
#  'Barry Jenkins',
#  'Princeton Holt',
#  'Mark Dennis',
#  'Michael Oblowitz',
#  "Karen O'Connor",
#  'Lina Roessler',
#  'Mira Nair',
#  'Kevin Phillips',
#  'Tom Tykwer',
#  'Michael Jai White',
#  'Luv Ranjan',
#  'Marco Schnabel',
#  'Gary Wheeler',
#  'Riley Keough',
#  'Gordon Douglas',
#  'Gerard Johnson',
#  'Ceyda Torun',
#  'Jesse Atlas',
#  'Michel Gondry',
#  'Christin Baker',
#  'Justin Routt',
#  'Boris Kunz',
#  'David Raymond',
#  'Christian Molina',
#  'Rob Schneider',
#  'Wil Shriner',
#  'M.S. Sripathy',
#  'Toyoo Ashida',
#  'Christian Tafdrup',
#  'Lawrence Kasanoff',
#  'Gelila Bekele',
#  'Tommy Lee Jones',
#  'Patrick Delage',
#  'Andrew Niccol',
#  'John Whitesell',
#  'Winston Azzopardi',
#  'Todd Field',
#  'Jonathan King',
#  'Dan Trachtenberg',
#  'Steve Jamison',
#  'Jessy Terrero',
#  'Kurt Neumann',
#  'John Gulager',
#  'Ken Finkleman',
#  'Kôji Morimoto',
#  'Levan Gabriadze',
#  'Francesco Cinquemani',
#  'Screaming Mad George',
#  'Phil Johnston',
#  'Bill Duke',
#  'John Carney',
#  'Galder Gaztelu-Urrutia',
#  'Jeremy Gillespie',
#  'Mel Damski',
#  'Sophia Banks',
#  'Goran Dukic',
#  'Ernest B. Schoedsack',
#  'Dean Fleischer Camp',
#  'David O. Russell',
#  'Lynne Littman',
#  'Richard Schenkman',
#  'Paddy Considine',
#  'Matthew Warchus',
#  'Xavier Palud',
#  'Terry George',
#  'Asia Argento',
#  'William Shatner',
#  'Michael Schwartz',
#  'Lloyd Kaufman',
#  'Alice Englert',
#  'Carl Theodor Dreyer',
#  'Chris Hardman',
#  'Klaus Menzel',
#  'Fernando Trueba',
#  'Soumendra Padhi',
#  'Tom Putnam',
#  'Ben Stiller',
#  'Hernán Zin',
#  'Penny Marshall',
#  'Ken Cunningham',
#  'Paul Haggis',
#  'Grégory Levasseur',
#  'Andy Palmer',
#  'Emilio Estevez',
#  'Marcus Adams',
#  'Vic Armstrong',
#  'Monika Mitchell',
#  'Martin Ritt',
#  'John Sayles',
#  'Robert Olsen',
#  'Lee Roy Kunz',
#  'Raja Gosnell',
#  'Arthur Rosson',
#  'Matthew Robinson',
#  'Björn Stein',
#  'Joe Penna',
#  'Tod Williams',
#  'Todd Stephens',
#  'Aaron Blaise',
#  'Srdjan Spasojevic',
#  'Oliver Stone',
#  'Dan Bradley',
#  'Lori Evans Taylor',
#  'Kurt Kuenne',
#  'Aaron Inman',
#  'Jeremy Dyson',
#  'Hemanth M. Rao',
#  'BJ McDonnell',
#  'David J. Burke',
#  'René Clément',
#  'Vincent Ward',
#  'Charlie Bean',
#  'Sean Olson',
#  'Tim Roth',
#  'Russell Crowe',
#  'Dae-woo Kim',
#  'Jonathan Straiton',
#  'Alex Proyas',
#  'Alan Taylor',
#  "James D'Arcy",
#  'Mark Romanek',
#  'Gavin Rothery',
#  'Kat Coiro',
#  'Tae-hwa Eom',
#  'Carrie Cracknell',
#  'George Roy Hill',
#  'Jennifer Yuh Nelson',
#  'Rob Zombie',
#  'Hamish Bennett',
#  'Brent McCorkle',
#  'Seth Larney',
#  'Jonah Feingold',
#  'Alex Kendrick',
#  'Gloria Katz',
#  'Kurando Mitsutake',
#  'Nancy Hower',
#  'Greg Berlanti',
#  'Andrew Hunt',
#  'Hoyt Yeatman',
#  'Sean Price Williams',
#  'Lee Chang-dong',
#  'Charlotte Regan',
#  'Zach Lipovsky',
#  'Lana Wachowski',
#  'Sophie Compton',
#  'Rick Jacobson',
#  'Justin Lin',
#  'James Bird',
#  'Lee Isaac Chung',
#  'Quentin Dupieux',
#  'Terry Gilliam',
#  'Gil Junger',
#  'Yann Gozlan',
#  'Jason Friedberg',
#  'Parker Finn',
#  'Brian Peter Falk',
#  'Roger Allers',
#  'Rod Amateau',
#  'Scott Moore',
#  'Philippe Diaz',
#  'Brian Gibson',
#  'Jonathan Prince',
#  'Alexandra Shiva',
#  'Lisa Joy',
#  'Maggie Gyllenhaal',
#  'James Kent',
#  'David Sandberg',
#  'John McNaughton',
#  'Matthias Temmermans',
#  'Bruce A. Evans',
#  'Joseph Kahn',
#  'Matthias Hoene',
#  'Anthony Minghella',
#  'Gonzalo López-Gallego',
#  'Bong Joon Ho',
#  'John Boorman',
#  'Kirsten Sheridan',
#  'Colin Cairnes',
#  'Michael Matthews',
#  'Brad Silberling',
#  'Terence Davies',
#  'Antonio Zavala Kugler',
#  'Josh Safdie',
#  ...}

# %% [markdown]
# Let's create a new Dataframe with the data for each Director.

# %%
#WARNING: Long process!

directors_data = pd.DataFrame(columns = ['name', 'titles', 'gross_max', 'gross_min', 'gross_mean', 'rating_max', 'rating_min', 'rating_mean'])

for d in directors:
    movies_by_d = df[df['director'].str.contains(d)]
    count = movies_by_d['title'].count()

    # Filter out movies with missing info on gross_worldwide
    movies_gross = movies_by_d[movies_by_d['gross_worldwide'] > 0]
    gross_max = movies_gross['gross_worldwide'].max()
    gross_min = movies_gross['gross_worldwide'].min()
    gross_mean = movies_gross['gross_worldwide'].mean()
    
    # Filter out movies with missing info on rating
    movies_rating = movies_by_d[movies_by_d['rating_int'] > 0]
    rating_max = movies_rating['rating_int'].max()
    rating_min = movies_rating['rating_int'].min()
    rating_mean = movies_rating['rating_int'].mean()

    
    titles = ''
    for index, movie in movies_by_d.iterrows():
        titles = titles + movie['title'] + ', '
    titles = titles[:-2]
    directors_data.loc[len(directors_data)] = [d, titles, gross_max, gross_min, gross_mean, rating_max, rating_min, rating_mean]

directors_data
# Out:
#                     name                                         titles  \
# 0              Billy Ray  Breach, Secret in Their Eyes, Shattered Glass
# 1         Channing Tatum                                            Dog
# 2     Brandon Cronenberg                       Infinity Pool, Possessor
# 3      Indar Dzhendubaev                                    I Am Dragon
# 4        Assaf Bernstein                                      Look Away
# ...                  ...                                            ...
# 4347       Joseph Winter                                     Deadstream
# 4348       Laura Poitras               All the Beauty and the Bloodshed
# 4349      Mario Miscione                                         Circle
# 4350       James Cummins                                   The Boneyard
# 4351          Glen Keane                                  Over the Moon
#
#        gross_max   gross_min    gross_mean  rating_max  rating_min  \
# 0     40953935.0   2944752.0  2.625123e+07        71.0        63.0
# 1     84774243.0  84774243.0  8.477424e+07        65.0        65.0
# 2      5183424.0    911180.0  3.047302e+06        65.0        60.0
# 3     10495305.0  10495305.0  1.049530e+07        68.0        68.0
# 4      1119537.0   1119537.0  1.119537e+06        58.0        58.0
# ...          ...         ...           ...         ...         ...
# 4347   1031519.0   1031519.0  1.031519e+06        64.0        64.0
# 4348   1483975.0   1483975.0  1.483975e+06        75.0        75.0
# 4349         NaN         NaN           NaN        60.0        60.0
# 4350         NaN         NaN           NaN        56.0        56.0
# 4351         NaN         NaN           NaN        63.0        63.0
#
#       rating_mean
# 0            68.0
# 1            65.0
# 2            62.5
# 3            68.0
# 4            58.0
# ...           ...
# 4347         64.0
# 4348         75.0
# 4349         60.0
# 4350         56.0
# 4351         63.0
#
# [4352 rows x 8 columns]

# %%
fig = px.scatter(directors_data, x='gross_mean', y='rating_mean', hover_data=['name', 'titles'])
fig.show()

# %% [markdown]
# Let's save the Director's DataSet.

# %%
directors_data.to_csv(os.path.join(data_path, 'directors.csv'))

# %% [markdown]
# [Back to Contents](#back)
